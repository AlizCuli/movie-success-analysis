# %% [markdown]
# # EDA TMDb cho bài toán dự đoán trước phát hành
#
# Notebook này tái tạo các bảng và hình dùng trong báo cáo. `revenue` chỉ được sử dụng để tạo nhãn `is_successful`; `popularity`, điểm đánh giá và lượt bình chọn không được phân tích như đặc trưng dự báo.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from IPython.display import Image, display
from src.eda_movies import run_eda

# %%
results = run_eda()

# %% [markdown]
# ## Chất lượng và phân bố dữ liệu

# %%
display(results['dataset_summary'])
display(results['missingness'])
display(Image(filename=ROOT / 'reports' / 'figures' / 'dataset_overview.png'))

# %% [markdown]
# ## Mối liên hệ với thành công tài chính

# %%
display(results['correlation'].loc[['is_successful']])
display(results['genre_collection'])
display(Image(filename=ROOT / 'reports' / 'figures' / 'pre_release_feature_associations.png'))

# %% [markdown]
# ## Phạm vi diễn giải
#
# Các kết quả là mô tả trên mẫu tối đa 100 phim phổ biến mỗi năm. Tương quan và chênh lệch tỷ lệ thành công không chứng minh quan hệ nhân quả.
